# %% [markdown]
# <div align="center">
#
# ### Lab 4
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 4: Predicting Stock Price with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In this lab, we explore the application of time-series datasets using Long Short-Term Memory (LSTM) networks, a type of recurrent neural network, to predict stock prices. Specifically, we will use historical price data from Nvidia to forecast the stock's price for the next day based on the prices of the previous N days. This approach is particularly relevant given the volatile nature of stock markets and the increasing reliance on automated trading systems.
#
# ### Objectives
#
# - To understand the fundamentals of LSTM networks and their application in time-series forecasting.
# - To develop a predictive model that can accurately forecast Nvidia's stock price for the next day using historical data.
#
# ### Dataset
#
# The dataset for this lab is from the "Huge Stock Market Dataset" available on Kaggle. This dataset includes daily prices and volumes for all US stocks and ETFs, with a specific focus on Nvidia (NVDA). The dataset features include:
#
# - **Date**: The recorded data points.
# - **Open**: The price at which the stock first traded upon the opening of an exchange on a given trading day.
# - **High**: The highest price at which the stock traded during the trading day.
# - **Low**: The lowest price at which the stock traded during the trading day.
# - **Close**: The price of the stock at closing time.
# - **Volume**: The number of shares or contracts traded in a security or an entire market during a given period.
# - **OpenInt**: The total number of outstanding derivative contracts, like options or futures. [More details here](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/discussion/121096)
#
# ### References
#
# - [Huge Stock Market Dataset](https://www.kaggle.com/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs) for the dataset used in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
import pandas as pd

df = pd.read_csv('./nvda.us.txt')
df
# Out:
#             Date      Open      High       Low     Close    Volume  OpenInt
# 0     1999-01-22    1.6238    1.8092    1.4379    1.5215  18297633        0
# 1     1999-01-25    1.6423    1.6980    1.5215    1.6793   3445279        0
# 2     1999-01-26    1.6980    1.7350    1.5311    1.5494   2320993        0
# 3     1999-01-27    1.5586    1.5957    1.4660    1.5494   1662658        0
# 4     1999-01-28    1.5494    1.5586    1.5311    1.5401   1540110        0
# ...          ...       ...       ...       ...       ...       ...      ...
# 4728  2017-11-06  207.2000  209.9800  206.7000  209.6300   9731783        0
# 4729  2017-11-07  210.5500  212.9000  210.0560  212.0000  10671815        0
# 4730  2017-11-08  211.8500  212.0000  207.2400  209.1600  13033902        0
# 4731  2017-11-09  205.2700  206.3300  200.3700  205.3200  23895006        0
# 4732  2017-11-10  213.0800  218.6700  211.6300  216.1400  31300857        0
#
# [4733 rows x 7 columns]

# %%
plot = df.plot('Date', 'High', figsize=(15, 5))

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4733 entries, 0 to 4732
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     4733 non-null   object
#  1   Open     4733 non-null   float64
#  2   High     4733 non-null   float64
#  3   Low      4733 non-null   float64
#  4   Close    4733 non-null   float64
#  5   Volume   4733 non-null   int64
#  6   OpenInt  4733 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 259.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (4733, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  4733.000000  4733.000000  4733.000000  4733.000000  4.733000e+03
# mean     20.796242    21.157332    20.420417    20.805404  1.615287e+07
# std      30.236284    30.615622    29.792958    30.263705  1.272446e+07
# min       1.298900     1.317500     1.233900     1.261900  0.000000e+00
# 25%       7.988300     8.247900     7.756400     7.978900  8.181100e+06
# 50%      12.963000    13.238000    12.721000    12.990000  1.390271e+07
# 75%      19.141000    19.418000    18.778000    19.106000  2.051602e+07
# max     213.080000   218.670000   211.630000   216.140000  2.496659e+08
#
#        OpenInt
# count   4733.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import random
import torch
import numpy as np
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# 確保 CUDA 運算的可重現性（但可能會影響運行速度）
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # 針對多 GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# %%
def create_sequences(input_data, output_data, window_size, step):
    sequences = []
    labels = []
    for i in range(0, len(input_data) - window_size, step):
        sequences.append(input_data[i:(i + window_size)])
        labels.append(output_data[i + window_size])
    return np.array(sequences), np.array(labels)

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Select features
features = df[['Open', 'High', 'Low', 'Close', 'Volume']]

# features = df[['High', 'Low', 'Close']]

labels = df['High'].shift(-1)  # Next day's high price as label

mask = ~labels.isna()
features = features[mask]
labels = labels[mask]

X, y = create_sequences(features, labels, window_size=10, step=2)

print(f'Shape of data X: {X.shape}')
print(f'Shape of data y: {y.shape}')

# split the hold-out tests
ind = np.linspace(0, len(X)-1, num=int(len(X)*0.1), dtype=int) # 10% hold-out
x_test = X[ind]
y_test = y[ind]
all_ind = np.arange(len(X))
remains_ind = np.delete(all_ind, ind)

X = X[remains_ind]
y = y[remains_ind]

# shuffle dataset
ind = np.random.permutation(len(X))
X = X[ind]
y = y[ind]
split_point = int(X.shape[0]*0.8)

x_train = X[:split_point]
y_train = y[:split_point]
x_val = X[split_point:]
y_val = y[split_point:]


# Normalization
train_mean = x_train.mean(axis=(0,1), keepdims=True)
train_std = x_train.std(axis=(0,1), keepdims=True)

x_train = (x_train - train_mean) / (train_std + 1e-8)
x_val = (x_val - train_mean) / (train_std + 1e-8)
x_test = (x_test - train_mean) / (train_std + 1e-8)



print(f'Shape of data x_train: {x_train.shape}')
print(f'Shape of data y_train: {y_train.shape}')
print(f'Shape of data x_val: {x_val.shape}')
print(f'Shape of data y_val: {y_val.shape}')
print(f'Shape of data x_test: {x_test.shape}')
print(f'Shape of data y_test: {y_test.shape}')

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).float()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).float()

x_test = torch.from_numpy(x_test).float()
y_test = torch.from_numpy(y_test).float()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in training and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Shape of data X: (2361, 10, 5)
# Shape of data y: (2361,)
# Shape of data x_train: (1700, 10, 5)
# Shape of data y_train: (1700,)
# Shape of data x_val: (425, 10, 5)
# Shape of data y_val: (425,)
# Shape of data x_test: (236, 10, 5)
# Shape of data y_test: (236,)
# Number of samples in training and validation are 1700 and 425.

# %% [markdown]
# ## B. Defining Neural Networks

# %%
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Thu May  1 15:09:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 56%   40C    P2             20W /  215W |    1748MiB /  12282MiB |      4%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      6516    C+G   ...B\system_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A      7028    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A      8088    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A      9528    C+G   ...ta\Local\Programs\Notion\Notion.exe      N/A      |
# |    0   N/A  N/A      9864    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A      9952    C+G   ...on\135.0.3179.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     10156    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     10168    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     10800    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     11852    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     11876    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     14340      C   ...anyu\.conda\envs\project\python.exe      N/A      |
# |    0   N/A  N/A     14552    C+G   ...al\Discord\app-1.0.9189\Discord.exe      N/A      |
# |    0   N/A  N/A     15136    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     18236    C+G   ...\cef\cef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A     19248    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     21220    C+G   ...ograms\cron-web\Notion Calendar.exe      N/A      |
# |    0   N/A  N/A     21556    C+G   ...ft Office\root\Office16\WINWORD.EXE      N/A      |
# |    0   N/A  N/A     23460    C+G   C:\Users\Guanyu\Downloads\AnyDesk.exe       N/A      |
# |    0   N/A  N/A     25376    C+G   ...on\135.0.3179.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     26768    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     27268    C+G   ...on\135.0.3179.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     28520    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     28976    C+G   ...995_x64__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A     32212    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []

epochs = 100

model = LSTMModel(input_dim=5, hidden_dim=500, num_layers=2, output_dim=1).cuda()
print(model)

best_val_loss = float('inf')

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()
        outputs = model(features).squeeze(-1)
        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)

    # Validation
    model.eval()
    total_val_loss = 0.0

    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()
            outputs = model(features).squeeze(-1)
            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

    avg_val_loss = total_val_loss / len(val_loader)

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'best_model.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Val loss: {avg_val_loss:.4f}, Best Val loss: {best_val_loss:.4f}')

    # Store performance
    train_losses.append(avg_train_loss)
    val_losses.append(avg_val_loss)
# Out:
# LSTMModel(
#   (lstm): LSTM(5, 500, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=500, out_features=1, bias=True)
# )
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 961.0433, Val loss: 901.2679, Best Val loss: 901.2679
# Epoch 2/100, Train loss: 757.4735, Val loss: 604.1643, Best Val loss: 604.1643
# Epoch 3/100, Train loss: 487.2037, Val loss: 377.5854, Best Val loss: 377.5854
# Epoch 4/100, Train loss: 338.8363, Val loss: 269.1577, Best Val loss: 269.1577
# Epoch 5/100, Train loss: 253.3711, Val loss: 169.8876, Best Val loss: 169.8876
# Epoch 6/100, Train loss: 175.3836, Val loss: 118.1236, Best Val loss: 118.1236
# Epoch 7/100, Train loss: 133.4418, Val loss: 87.6589, Best Val loss: 87.6589
# Epoch 8/100, Train loss: 105.7121, Val loss: 68.5237, Best Val loss: 68.5237
# Epoch 9/100, Train loss: 90.7383, Val loss: 54.5789, Best Val loss: 54.5789
# Epoch 10/100, Train loss: 66.9600, Val loss: 41.1780, Best Val loss: 41.1780
# Epoch 11/100, Train loss: 53.9259, Val loss: 34.4601, Best Val loss: 34.4601
# Epoch 12/100, Train loss: 42.2268, Val loss: 34.2288, Best Val loss: 34.2288
# Epoch 13/100, Train loss: 35.3828, Val loss: 19.2232, Best Val loss: 19.2232
# Epoch 14/100, Train loss: 26.9545, Val loss: 15.1147, Best Val loss: 15.1147
# Epoch 15/100, Train loss: 29.2640, Val loss: 11.6588, Best Val loss: 11.6588
# Epoch 16/100, Train loss: 19.1375, Val loss: 13.5045, Best Val loss: 11.6588
# Epoch 17/100, Train loss: 17.3882, Val loss: 9.9339, Best Val loss: 9.9339
# Epoch 18/100, Train loss: 15.1490, Val loss: 9.0550, Best Val loss: 9.0550
# Epoch 19/100, Train loss: 13.9037, Val loss: 8.2781, Best Val loss: 8.2781
# Epoch 20/100, Train loss: 13.2536, Val loss: 10.5428, Best Val loss: 8.2781
# Epoch 21/100, Train loss: 16.7100, Val loss: 8.8829, Best Val loss: 8.2781
# Epoch 22/100, Train loss: 13.3421, Val loss: 11.0279, Best Val loss: 8.2781
# Epoch 23/100, Train loss: 11.0949, Val loss: 8.9529, Best Val loss: 8.2781
# Epoch 24/100, Train loss: 9.2085, Val loss: 8.8845, Best Val loss: 8.2781
# Epoch 25/100, Train loss: 9.5501, Val loss: 6.8061, Best Val loss: 6.8061
# Epoch 26/100, Train loss: 9.2850, Val loss: 8.9213, Best Val loss: 6.8061
# Epoch 27/100, Train loss: 7.6043, Val loss: 6.7520, Best Val loss: 6.7520
# Epoch 28/100, Train loss: 7.6919, Val loss: 7.1096, Best Val loss: 6.7520
# Epoch 29/100, Train loss: 8.5777, Val loss: 6.1932, Best Val loss: 6.1932
# Epoch 30/100, Train loss: 9.1184, Val loss: 7.2919, Best Val loss: 6.1932
# Epoch 31/100, Train loss: 6.8130, Val loss: 9.2099, Best Val loss: 6.1932
# Epoch 32/100, Train loss: 10.4789, Val loss: 7.9575, Best Val loss: 6.1932
# Epoch 33/100, Train loss: 7.5460, Val loss: 7.9959, Best Val loss: 6.1932
# Epoch 34/100, Train loss: 6.8737, Val loss: 5.9769, Best Val loss: 5.9769
# Epoch 35/100, Train loss: 5.6291, Val loss: 5.6699, Best Val loss: 5.6699
# Epoch 36/100, Train loss: 6.1611, Val loss: 5.5039, Best Val loss: 5.5039
# Epoch 37/100, Train loss: 6.2805, Val loss: 5.6251, Best Val loss: 5.5039
# Epoch 38/100, Train loss: 6.7106, Val loss: 11.4892, Best Val loss: 5.5039
# Epoch 39/100, Train loss: 6.0831, Val loss: 5.3744, Best Val loss: 5.3744
# Epoch 40/100, Train loss: 5.5161, Val loss: 6.8006, Best Val loss: 5.3744
# Epoch 41/100, Train loss: 5.7626, Val loss: 6.6330, Best Val loss: 5.3744
# Epoch 42/100, Train loss: 5.8381, Val loss: 6.2093, Best Val loss: 5.3744
# Epoch 43/100, Train loss: 5.2543, Val loss: 5.9350, Best Val loss: 5.3744
# Epoch 44/100, Train loss: 5.0842, Val loss: 5.3315, Best Val loss: 5.3315
# Epoch 45/100, Train loss: 5.1359, Val loss: 5.5273, Best Val loss: 5.3315
# Epoch 46/100, Train loss: 4.8268, Val loss: 8.7166, Best Val loss: 5.3315
# Epoch 47/100, Train loss: 4.6700, Val loss: 5.3716, Best Val loss: 5.3315
# Epoch 48/100, Train loss: 4.2549, Val loss: 4.6704, Best Val loss: 4.6704
# Epoch 49/100, Train loss: 3.8105, Val loss: 4.9185, Best Val loss: 4.6704
# Epoch 50/100, Train loss: 3.9457, Val loss: 5.5979, Best Val loss: 4.6704
# Epoch 51/100, Train loss: 5.2366, Val loss: 5.5207, Best Val loss: 4.6704
# Epoch 52/100, Train loss: 4.0778, Val loss: 5.3111, Best Val loss: 4.6704
# Epoch 53/100, Train loss: 4.6417, Val loss: 4.7642, Best Val loss: 4.6704
# Epoch 54/100, Train loss: 3.7920, Val loss: 5.2915, Best Val loss: 4.6704
# Epoch 55/100, Train loss: 3.6188, Val loss: 4.8144, Best Val loss: 4.6704
# Epoch 56/100, Train loss: 4.5998, Val loss: 4.8279, Best Val loss: 4.6704
# Epoch 57/100, Train loss: 5.7577, Val loss: 6.9776, Best Val loss: 4.6704
# Epoch 58/100, Train loss: 3.7894, Val loss: 4.4911, Best Val loss: 4.4911
# Epoch 59/100, Train loss: 3.4982, Val loss: 5.1279, Best Val loss: 4.4911
# Epoch 60/100, Train loss: 3.2760, Val loss: 5.9180, Best Val loss: 4.4911
# Epoch 61/100, Train loss: 3.4265, Val loss: 5.6646, Best Val loss: 4.4911
# Epoch 62/100, Train loss: 3.3334, Val loss: 4.6925, Best Val loss: 4.4911
# Epoch 63/100, Train loss: 3.6416, Val loss: 4.5061, Best Val loss: 4.4911
# Epoch 64/100, Train loss: 3.3737, Val loss: 4.4616, Best Val loss: 4.4616
# Epoch 65/100, Train loss: 3.5852, Val loss: 4.4154, Best Val loss: 4.4154
# Epoch 66/100, Train loss: 3.0612, Val loss: 4.5714, Best Val loss: 4.4154
# Epoch 67/100, Train loss: 3.1583, Val loss: 4.4165, Best Val loss: 4.4154
# Epoch 68/100, Train loss: 3.2703, Val loss: 4.5804, Best Val loss: 4.4154
# Epoch 69/100, Train loss: 3.2547, Val loss: 5.3199, Best Val loss: 4.4154
# Epoch 70/100, Train loss: 3.1754, Val loss: 5.0344, Best Val loss: 4.4154
# Epoch 71/100, Train loss: 3.0424, Val loss: 4.4235, Best Val loss: 4.4154
# Epoch 72/100, Train loss: 3.0503, Val loss: 4.1829, Best Val loss: 4.1829
# Epoch 73/100, Train loss: 3.0263, Val loss: 4.8894, Best Val loss: 4.1829
# Epoch 74/100, Train loss: 3.0090, Val loss: 4.6664, Best Val loss: 4.1829
# Epoch 75/100, Train loss: 3.0371, Val loss: 4.3123, Best Val loss: 4.1829
# Epoch 76/100, Train loss: 2.8516, Val loss: 4.3174, Best Val loss: 4.1829
# Epoch 77/100, Train loss: 2.8729, Val loss: 4.2122, Best Val loss: 4.1829
# Epoch 78/100, Train loss: 2.8918, Val loss: 4.4103, Best Val loss: 4.1829
# Epoch 79/100, Train loss: 2.7695, Val loss: 4.3808, Best Val loss: 4.1829
# Epoch 80/100, Train loss: 2.8099, Val loss: 4.3135, Best Val loss: 4.1829
# Epoch 81/100, Train loss: 2.8107, Val loss: 3.9862, Best Val loss: 3.9862
# Epoch 82/100, Train loss: 2.6153, Val loss: 4.1839, Best Val loss: 3.9862
# Epoch 83/100, Train loss: 2.6051, Val loss: 3.9514, Best Val loss: 3.9514
# Epoch 84/100, Train loss: 2.5102, Val loss: 3.9499, Best Val loss: 3.9499
# Epoch 85/100, Train loss: 2.4679, Val loss: 3.9019, Best Val loss: 3.9019
# Epoch 86/100, Train loss: 2.4011, Val loss: 3.8391, Best Val loss: 3.8391
# Epoch 87/100, Train loss: 2.3653, Val loss: 3.8931, Best Val loss: 3.8391
# Epoch 88/100, Train loss: 2.3347, Val loss: 3.9844, Best Val loss: 3.8391
# Epoch 89/100, Train loss: 2.3006, Val loss: 3.8341, Best Val loss: 3.8341
# Epoch 90/100, Train loss: 2.2588, Val loss: 3.7791, Best Val loss: 3.7791
# Epoch 91/100, Train loss: 2.2463, Val loss: 4.0097, Best Val loss: 3.7791
# Epoch 92/100, Train loss: 2.2307, Val loss: 3.7456, Best Val loss: 3.7456
# Epoch 93/100, Train loss: 2.1635, Val loss: 3.7638, Best Val loss: 3.7456
# Epoch 94/100, Train loss: 2.1761, Val loss: 3.8073, Best Val loss: 3.7456
# Epoch 95/100, Train loss: 2.1264, Val loss: 3.7600, Best Val loss: 3.7456
# Epoch 96/100, Train loss: 2.1195, Val loss: 3.7315, Best Val loss: 3.7315
# Epoch 97/100, Train loss: 2.1347, Val loss: 3.7661, Best Val loss: 3.7315
# Epoch 98/100, Train loss: 2.1212, Val loss: 3.7423, Best Val loss: 3.7315
# Epoch 99/100, Train loss: 2.2284, Val loss: 3.7421, Best Val loss: 3.7315
# Epoch 100/100, Train loss: 2.8977, Val loss: 3.7403, Best Val loss: 3.7315

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(train_losses)
plt.plot(val_losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# Load the trained weights
model.load_state_dict(torch.load('best_model.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

pred_value = []
actual_value = []
with torch.no_grad():
    for features, labels in test_loader:
        features = features.cuda()
        outputs = model(features).squeeze(-1)
        pred_value.append(outputs.cpu())
        actual_value.append(labels)

pred_value = torch.cat(pred_value)
actual_value = torch.cat(actual_value)

print("Test MSE: {:.4f}".format(mean_squared_error(pred_value, actual_value)))
# Out:
# Test MSE: 2.6778

# %%
plt.figure(figsize=(10, 5))
plt.plot(pred_value[:])
plt.plot(actual_value[:])
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend(['Pred', 'Actual'])

plt.show()
