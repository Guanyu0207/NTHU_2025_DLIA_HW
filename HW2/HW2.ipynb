# %% [markdown]
# <div align="center">
#
# ###### Lab 2
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 2: Predicting Heart Disease with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In the realm of healthcare, early detection and accurate prediction of diseases play a crucial role in patient care and management. Heart disease remains one of the leading causes of mortality worldwide, making the development of effective diagnostic tools essential. This lab leverages deep learning to predict the presence of heart disease in patients using a subset of 14 key attributes from the Cleveland Heart Disease Database. The objective is to explore and apply deep learning techniques to distinguish between the presence and absence of heart disease based on clinical parameters.
#
# Throughout this lab, you'll engage with the following key activities:
# - Use [Pandas](https://pandas.pydata.org) to process the CSV files.
# - Use [PyTorch](https://pytorch.org) to build an Artificial Neural Network (ANN) to fit the dataset.
# - Evaluate the performance of the trained model to understand its accuracy.
#
# ### Attribute Information
#
# 1. age: Age of the patient in years
# 2. sex: (Male/Female)
# 3. cp: Chest pain type (4 types: low, medium, high, and severe)
# 4. trestbps: Resting blood pressure
# 5. chol: Serum cholesterol in mg/dl
# 6. fbs: Fasting blood sugar > 120 mg/dl
# 7. restecg: Resting electrocardiographic results (values 0,1,2)
# 8. thalach: Maximum heart rate achieved
# 9. exang: Exercise induced angina
# 10. oldpeak: Oldpeak = ST depression induced by exercise relative to rest
# 11. slope: The slope of the peak exercise ST segment
# 12. ca: Number of major vessels (0-3) colored by fluoroscopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversible defect
# 14. target: target have disease or not (1=yes, 0=no)
#
# ### References
# - [UCI Heart Disease Data](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data) for the dataset we use in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
import pandas as pd

df = pd.read_csv('heart_dataset_train_all.csv')
df
# Out:
#      age     sex      cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0     41    Male  medium     105.0  198.0    0      1.0    168.0      0
# 1     65  Female     low     120.0  177.0    0      1.0    140.0      0
# 2     44  Female  medium     130.0  219.0    0      0.0    188.0      0
# 3     54  Female    high     125.0  273.0    0      0.0    152.0      0
# 4     51  Female  severe     125.0  213.0    0      0.0    125.0      1
# ..   ...     ...     ...       ...    ...  ...      ...      ...    ...
# 268   40  Female     low     110.0  167.0    0      0.0    114.0      1
# 269   60  Female     low     117.0  230.0    1      1.0    160.0      1
# 270   64  Female    high     140.0  335.0    0      1.0    158.0      0
# 271   43  Female     low     120.0  177.0    0      0.0    120.0      1
# 272   57  Female     low     150.0  276.0    0      0.0    112.0      1
#
#      oldpeak  slope  ca  thal  target
# 0        0.0    2.0   1   2.0     1.0
# 1        0.4    2.0   0   3.0     1.0
# 2        0.0    2.0   0   2.0     1.0
# 3        0.5    0.0   1   2.0     1.0
# 4        1.4    2.0   1   2.0     1.0
# ..       ...    ...  ..   ...     ...
# 268      2.0    1.0   0   3.0     0.0
# 269      1.4    2.0   2   3.0     0.0
# 270      0.0    2.0   0   2.0     0.0
# 271      2.5    1.0   0   3.0     0.0
# 272      0.6    1.0   1   1.0     0.0
#
# [273 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       273 non-null    int64
#  1   sex       272 non-null    object
#  2   cp        272 non-null    object
#  3   trestbps  272 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       273 non-null    int64
#  6   restecg   272 non-null    float64
#  7   thalach   272 non-null    float64
#  8   exang     273 non-null    int64
#  9   oldpeak   273 non-null    float64
#  10  slope     271 non-null    float64
#  11  ca        273 non-null    int64
#  12  thal      272 non-null    float64
#  13  target    272 non-null    float64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 30.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# age         0
# sex         1
# cp          1
# trestbps    1
# chol        2
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       2
# ca          0
# thal        1
# target      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (270, 14)

# %%
# Mapping 'sex' descriptions to numbers
sex_description = {
    'Male': 0,
    'Female': 1,
}
df.loc[:, 'sex'] = df['sex'].map(sex_description)

# Mapping 'cp' (chest pain) descriptions to numbers
pain_description = {
    'low': 0,
    'medium': 1,
    'high': 2,
    'severe': 3
}
df.loc[:, 'cp'] = df['cp'].map(pain_description)

df
# Out:
#      age sex cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     41   0  1     105.0  198.0    0      1.0    168.0      0      0.0
# 1     65   1  0     120.0  177.0    0      1.0    140.0      0      0.4
# 2     44   1  1     130.0  219.0    0      0.0    188.0      0      0.0
# 3     54   1  2     125.0  273.0    0      0.0    152.0      0      0.5
# 4     51   1  3     125.0  213.0    0      0.0    125.0      1      1.4
# ..   ...  .. ..       ...    ...  ...      ...      ...    ...      ...
# 268   40   1  0     110.0  167.0    0      0.0    114.0      1      2.0
# 269   60   1  0     117.0  230.0    1      1.0    160.0      1      1.4
# 270   64   1  2     140.0  335.0    0      1.0    158.0      0      0.0
# 271   43   1  0     120.0  177.0    0      0.0    120.0      1      2.5
# 272   57   1  0     150.0  276.0    0      0.0    112.0      1      0.6
#
#      slope  ca  thal  target
# 0      2.0   1   2.0     1.0
# 1      2.0   0   3.0     1.0
# 2      2.0   0   2.0     1.0
# 3      0.0   1   2.0     1.0
# 4      2.0   1   2.0     1.0
# ..     ...  ..   ...     ...
# 268    1.0   0   3.0     0.0
# 269    2.0   2   3.0     0.0
# 270    2.0   0   2.0     0.0
# 271    1.0   0   3.0     0.0
# 272    1.0   1   1.0     0.0
#
# [270 rows x 14 columns]

# %%
df.describe()
# Out:
#               age    trestbps        chol         fbs     restecg     thalach  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.385185  131.525926  245.607407    0.151852    0.522222  149.807407
# std      9.149713   17.904675   51.529411    0.359544    0.529314   23.217253
# min     29.000000   94.000000  126.000000    0.000000    0.000000   71.000000
# 25%     47.250000  120.000000  210.250000    0.000000    0.000000  134.500000
# trestbps  0.068690 -0.173239
# chol      0.121280 -0.096773
# fbs      -0.004972 -0.068845
# restecg  -0.003377  0.101817
# thalach  -0.078637  0.432687
# exang     0.189253 -0.457502
# oldpeak   0.200315 -0.443504
# slope    -0.090606  0.363983
# ca        0.136160 -0.391031
# thal      1.000000 -0.311701
# target   -0.311701  1.000000

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import numpy as np

np_data = df.values
np_data.shape
# Out:
# (270, 14)

# %%
split_point = int(np_data.shape[0]*0.7)

np.random.shuffle(np_data)

x_train = np_data[:split_point, :13]
y_train = np_data[:split_point, 13]
x_val = np_data[split_point:, :13]
y_val = np_data[split_point:, 13]

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# Convert to PyTorch tensors
x_train = np.array(x_train, dtype=np.float32)
y_train = np.array(y_train, dtype=np.int64)
x_val = np.array(x_val, dtype=np.float32)
y_val = np.array(y_val, dtype=np.int64)

x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Number of samples in train and validation are 189 and 81.

# %% [markdown]
# ## B. Defining Neural Networks
#
# In PyTorch, we can use **class** to define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(13, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        ).cuda()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Wed Mar 26 21:24:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | 56%   42C    P2             30W /  215W |    1645MiB /  12282MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      6124    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A      6400    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A      6492    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A      6716    C+G   ...al\Discord\app-1.0.9186\Discord.exe      N/A      |
# |    0   N/A  N/A      7304    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A      7588    C+G   ...ata\Local\LINE\bin\current\LINE.exe      N/A      |
# |    0   N/A  N/A      9976    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     10580    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     10656    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     10816    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     11848      C   ...anyu\.conda\envs\project\python.exe      N/A      |
# |    0   N/A  N/A     11936    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     12796    C+G   ...on\134.0.3124.83\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     15052    C+G   ...\cef\cef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A     16240    C+G   ...849_x64__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A     18028    C+G   ...ta\Local\Programs\Notion\Notion.exe      N/A      |
# |    0   N/A  N/A     18044    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A     18908    C+G   ...ograms\cron-web\Notion Calendar.exe      N/A      |
# |    0   N/A  N/A     19464    C+G   ...on\134.0.3124.83\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     20312    C+G   ...on\134.0.3124.83\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     20984    C+G   ...849_x64__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A     23488    C+G   ...B\system_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A     24768    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     25948    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     29944    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import random
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# 確保 CUDA 運算的可重現性（但可能會影響運行速度）
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # 針對多 GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the provided table
epochs = [100, 200, 300]
learning_rates = [0.01, 0.001, 0.0001]

# Training accuracy
train_accuracies = {
    0.01: [89.95, 92.59, 96.30],
    0.001: [86.77, 89.42, 92.59],
    0.0001: [76.19, 80.42, 85.71]
}

# Validation accuracy
val_accuracies = {
    0.01: [79.01, 76.54, 75.31],
    0.001: [79.01, 75.31, 75.31],
    0.0001: [67.90, 75.31, 74.07]
}

# Training loss
train_losses = {
    0.01: [0.2729, 0.1944, 0.1173],
    0.001: [0.3484, 0.2699, 0.2196],
    0.0001: [0.4826, 0.4239, 0.3733]
}

# Validation loss
val_losses = {
    0.01: [0.4941, 0.6515, 1.0342],
    0.001: [0.4613, 0.4820, 0.5658],
    0.0001: [0.5888, 0.5690, 0.5658]
}

# Create a 2x2 grid of subplots
plt.figure(figsize=(16, 12))

# Training Accuracy
plt.subplot(2, 2, 1)
for lr in learning_rates:
    plt.plot(epochs, train_accuracies[lr], marker='o', label=f'LR {lr}')
plt.title('Training Accuracy', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Accuracy (%)', fontsize=10)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Validation Accuracy
plt.subplot(2, 2, 2)
for lr in learning_rates:
    plt.plot(epochs, val_accuracies[lr], marker='o', label=f'LR {lr}')
plt.title('Validation Accuracy', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Accuracy (%)', fontsize=10)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Training Loss
plt.subplot(2, 2, 3)
for lr in learning_rates:
    plt.plot(epochs, train_losses[lr], marker='o', label=f'LR {lr}')
plt.title('Training Loss', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Validation Loss
plt.subplot(2, 2, 4)
for lr in learning_rates:
    plt.plot(epochs, val_losses[lr], marker='o', label=f'LR {lr}')
plt.title('Validation Loss', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the provided table
epochs = [100, 200, 300]
learning_rates = [0.01, 0.001, 0.0001]

# Accuracies
accuracies = {
    0.01: {
        'train': [89.95, 92.59, 96.30],
        'valid': [79.01, 76.54, 75.31],
        'test': [70.97, 83.87, 74.19]
    },
    0.001: {
        'train': [86.77, 89.42, 92.59],
        'valid': [79.01, 75.31, 75.31],
        'test': [70.97, 74.19, 74.19]
    },
    0.0001: {
        'train': [76.19, 80.42, 85.71],
        'valid': [67.90, 75.31, 74.07],
        'test': [58.06, 70.97, 70.97]
    }
}

# Losses
losses = {
    0.01: {
        'train': [0.2729, 0.1944, 0.1173],
        'valid': [0.4941, 0.6515, 1.0342],
        'test': [0.4597, 0.3955, 0.3976]
    },
    0.001: {
        'train': [0.3484, 0.2699, 0.2196],
        'valid': [0.4613, 0.4820, 0.5658],
        'test': [0.5350, 0.5347, 0.4991]
    },
    0.0001: {
        'train': [0.4826, 0.4239, 0.3733],
        'valid': [0.5888, 0.5690, 0.5658],
        'test': [0.6807, 0.5492, 0.5471]
    }
}

# Create figures
plt.figure(figsize=(16, 10))

# Accuracy Plot
plt.subplot(1, 2, 1)
line_styles = ['-', '--', '-.']
markers = ['o', 's', '^']
colors = ['blue', 'green', 'red']

for i, lr in enumerate(learning_rates):
    plt.plot(epochs, accuracies[lr]['train'], 
             color=colors[0], 
             linestyle=line_styles[i], 
             marker=markers[0], 
             label=f'Train LR {lr}')
    plt.plot(epochs, accuracies[lr]['valid'], 
             color=colors[1], 
             linestyle=line_styles[i], 
             marker=markers[1], 
             label=f'Valid LR {lr}')
    plt.plot(epochs, accuracies[lr]['test'], 
             color=colors[2], 
             linestyle=line_styles[i], 
             marker=markers[2], 
             label=f'Test LR {lr}')

plt.title('Accuracy Across Train, Validation, and Test Sets', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Accuracy (%)', fontsize=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)

# Loss Plot
plt.subplot(1, 2, 2)
for i, lr in enumerate(learning_rates):
    plt.plot(epochs, losses[lr]['train'], 
             color=colors[0], 
             linestyle=line_styles[i], 
             marker=markers[0], 
             label=f'Train LR {lr}')
    plt.plot(epochs, losses[lr]['valid'], 
             color=colors[1], 
             linestyle=line_styles[i], 
             marker=markers[1], 
             label=f'Valid LR {lr}')
    plt.plot(epochs, losses[lr]['test'], 
             color=colors[2], 
             linestyle=line_styles[i], 
             marker=markers[2], 
             label=f'Test LR {lr}')

plt.title('Loss Across Train, Validation, and Test Sets', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the provided table
epochs = [100, 200, 300]
learning_rates = [0.01, 0.001, 0.0001]

# Accuracies
accuracies = {
    0.01: {
        'train': [89.95, 92.59, 96.30],
        'valid': [79.01, 76.54, 75.31]
    },
    0.001: {
        'train': [86.77, 89.42, 92.59],
        'valid': [79.01, 75.31, 75.31]
    },
    0.0001: {
        'train': [76.19, 80.42, 85.71],
        'valid': [67.90, 75.31, 74.07]
    }
}

# Losses
losses = {
    0.01: {
        'train': [0.2729, 0.1944, 0.1173],
        'valid': [0.4941, 0.6515, 1.0342]
    },
    0.001: {
        'train': [0.3484, 0.2699, 0.2196],
        'valid': [0.4613, 0.4820, 0.5658]
    },
    0.0001: {
        'train': [0.4826, 0.4239, 0.3733],
        'valid': [0.5888, 0.5690, 0.5658]
    }
}

# Create figures
plt.figure(figsize=(16, 6))

# Accuracy Plot
plt.subplot(1, 2, 1)
line_styles = ['-', '--', '-.']
markers = ['o', 's']
colors = ['blue', 'green']

for i, lr in enumerate(learning_rates):
    plt.plot(epochs, accuracies[lr]['train'], 
             color=colors[0], 
             linestyle=line_styles[i], 
             marker=markers[0], 
             label=f'Train LR {lr}')
    plt.plot(epochs, accuracies[lr]['valid'], 
             color=colors[1], 
             linestyle=line_styles[i], 
             marker=markers[1], 
             label=f'Valid LR {lr}')

plt.title('Accuracy for Train and Validation Sets', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Accuracy (%)', fontsize=10)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Loss Plot
plt.subplot(1, 2, 2)
for i, lr in enumerate(learning_rates):
    plt.plot(epochs, losses[lr]['train'], 
             color=colors[0], 
             linestyle=line_styles[i], 
             marker=markers[0], 
             label=f'Train LR {lr}')
    plt.plot(epochs, losses[lr]['valid'], 
             color=colors[1], 
             linestyle=line_styles[i], 
             marker=markers[1], 
             label=f'Valid LR {lr}')

plt.title('Loss for Train and Validation Sets', fontsize=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 300

model = Model()
# print(model)

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-2)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()

            outputs = model(features)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch 1/300, Train loss: 35.8104, Train acc: 51.8519%, Val loss: 0.8727, Val acc: 58.0247%, Best Val loss: 0.8727 Best Val acc: 58.02%
# Epoch 2/300, Train loss: 2.1081, Train acc: 57.1429%, Val loss: 1.4820, Val acc: 54.3210%, Best Val loss: 0.8727 Best Val acc: 58.02%
# Epoch 3/300, Train loss: 1.3235, Train acc: 53.9683%, Val loss: 0.7574, Val acc: 60.4938%, Best Val loss: 0.7574 Best Val acc: 60.49%
# Epoch 4/300, Train loss: 0.7348, Train acc: 68.2540%, Val loss: 0.7693, Val acc: 59.2593%, Best Val loss: 0.7574 Best Val acc: 60.49%
# Epoch 5/300, Train loss: 0.6697, Train acc: 68.2540%, Val loss: 0.6329, Val acc: 62.9630%, Best Val loss: 0.6329 Best Val acc: 62.96%
# Epoch 6/300, Train loss: 0.6288, Train acc: 65.0794%, Val loss: 0.5814, Val acc: 69.1358%, Best Val loss: 0.5814 Best Val acc: 69.14%
# Epoch 7/300, Train loss: 0.6052, Train acc: 68.2540%, Val loss: 0.6533, Val acc: 64.1975%, Best Val loss: 0.5814 Best Val acc: 69.14%
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the provided table
epochs = [100, 200, 300]

# Accuracies for each learning rate
accuracies_data = {
    0.01: {
        'train': [89.95, 92.59, 96.30],
        'valid': [79.01, 76.54, 75.31],
        'test': [70.97, 83.87, 74.19]
    },
    0.001: {
        'train': [86.77, 89.42, 92.59],
        'valid': [79.01, 75.31, 75.31],
        'test': [70.97, 74.19, 74.19]
    },
    0.0001: {
        'train': [76.19, 80.42, 85.71],
        'valid': [67.90, 75.31, 74.07],
        'test': [58.06, 70.97, 70.97]
    }
}

# Create the figure with three subplots
plt.figure(figsize=(15, 5))

# Color palette
colors = ['blue', 'green', 'red']

# Iterate through learning rates
for i, lr in enumerate([0.01, 0.001, 0.0001], 1):
    plt.subplot(1, 3, i)
    
    # Prepare data for current learning rate
    train_acc = accuracies_data[lr]['train']
    valid_acc = accuracies_data[lr]['valid']
    test_acc = accuracies_data[lr]['test']
    
    # Create bar positions
    x = np.arange(len(epochs))
    width = 0.25
    
    # Plot bars
    plt.bar(x - width, train_acc, width, label='Train', color=colors[0])
    plt.bar(x, valid_acc, width, label='Valid', color=colors[1])
    plt.bar(x + width, test_acc, width, label='Test', color=colors[2])
    
    # Customize the plot
    plt.title(f'Learning Rate: {lr}', fontweight='bold')
    plt.xlabel('Epochs', fontweight='bold')
    plt.ylabel('Accuracy (%)', fontweight='bold')
    plt.xticks(x, epochs)
    plt.legend()
    
    # Add value labels on the bars
    for j, (train_val, valid_val, test_val) in enumerate(zip(train_acc, valid_acc, test_acc)):
        plt.text(j - width, train_val, f'{train_val:.2f}%', 
                 ha='center', va='bottom', fontsize=8)
        plt.text(j, valid_val, f'{valid_val:.2f}%', 
                 ha='center', va='bottom', fontsize=8)
        plt.text(j + width, test_val, f'{test_val:.2f}%', 
                 ha='center', va='bottom', fontsize=8)
    
    # Add grid for better readability
    plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# read test file
test_data = pd.read_csv('heart_dataset_test.csv')
test_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   50    0   2       120   219    0        1      158      0      1.6      1
# 1   58    0   2       120   340    0        1      172      0      0.0      2
# 2   66    0   3       150   226    0        1      114      0      2.6      0
# 3   43    1   0       150   247    0        1      171      0      1.5      2
# 4   69    0   3       140   239    0        1      151      0      1.8      2
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   2     2       1

# %%
test_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
test_data = test_data.values
test_data.shape
# Out:
# (31, 14)

# %%
# Convert to PyTorch tensors
x_test = torch.from_numpy(test_data[:, :13]).float()
y_test = torch.from_numpy(test_data[:, 13]).long()

# Create datasets
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

test_loss = 0.0
criterion = nn.CrossEntropyLoss()

with torch.no_grad():
    for features, labels in test_loader:

        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)
        
        loss = criterion(outputs, labels)
        test_loss += loss.item() 

        predicted = outputs.argmax(-1)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

avg_test_loss = test_loss / len(test_loader)
test_accuracy = 100. * test_correct / test_total

print(f'Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}%')
# Out:
# Test Loss: 0.5471, Test Accuracy: 70.9677%
